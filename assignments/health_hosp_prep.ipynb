# %%
import pandas as pd
import glob
import os
import numpy as np

# %% [markdown]
# ## Health data for Number of Hospitilizations, women
#
# * prep in chunks of seven files. Seven because the next seven files contain the exact same categories that must be added, but are just files for different municipalities.
# * Remove duplicate rows and keep first, as each file contains a row for municipality_code = 0, which is Total Denmark Average. As we only need this row one time, we remove the duplicates
# * Create new columns depending on the file chunk.

# %%
# Input all csv files at once
path = "Health_Hospitalizations_Women/"
all_files_health_hosp_w = glob.glob(path + "/*.csv")
# sort all files by date modified
all_files_health_hosp_w.sort(key=os.path.getmtime)

li_mapper_health_hosp_w = map(lambda filename: pd.read_csv(filename, index_col=None, header=0), all_files_health_hosp_w)
file_list_health_hosp_w = list(li_mapper_health_hosp_w)

# %%
# Women, age 18-29, Danish, No higher education
healthHospW_1 = pd.concat(file_list_health_hosp_w[0:7], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_1.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_1['gender'] = 'Women'
healthHospW_1['age'] = '18-29'
healthHospW_1['ethnicity'] = 'Danish'
healthHospW_1['education'] = 'No higher education'

# Women, age 18-29, Danish, Higher education
healthHospW_2 = pd.concat(file_list_health_hosp_w[7:14], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_2.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_2['gender'] = 'Women'
healthHospW_2['age'] = '18-29'
healthHospW_2['ethnicity'] = 'Danish'
healthHospW_2['education'] = 'Higher education'

# Women, age 18-29, Immigrants and descendants, No higher education
healthHospW_3 = pd.concat(file_list_health_hosp_w[14:21], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_3.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_3['gender'] = 'Women'
healthHospW_3['age'] = '18-29'
healthHospW_3['ethnicity'] = 'Immigrants and descendants'
healthHospW_3['education'] = 'No higher education'

# Women, age 18-29, Immigrants and descendants, Higher education
healthHospW_4 = pd.concat(file_list_health_hosp_w[21:28], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_4.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_4['gender'] = 'Women'
healthHospW_4['age'] = '18-29'
healthHospW_4['ethnicity'] = 'Immigrants and descendants'
healthHospW_4['education'] = 'Higher education'

# Women, age 18-29, Non-western immigrants and descendants, No higher education
healthHospW_5 = pd.concat(file_list_health_hosp_w[28:35], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_5.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_5['gender'] = 'Women'
healthHospW_5['age'] = '18-29'
healthHospW_5['ethnicity'] = 'Non-western immigrants and descendants'
healthHospW_5['education'] = 'No higher education'

# Women, age 18-29, Non-western immigrants and descendants, Higher education
healthHospW_6 = pd.concat(file_list_health_hosp_w[35:42], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_6.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_6['gender'] = 'Women'
healthHospW_6['age'] = '18-29'
healthHospW_6['ethnicity'] = 'Non-western immigrants and descendants'
healthHospW_6['education'] = 'Higher education'

# Women, age 30-39, Danish, No higher education
healthHospW_7 = pd.concat(file_list_health_hosp_w[42:49], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_7.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_7['gender'] = 'Women'
healthHospW_7['age'] = '30-39'
healthHospW_7['ethnicity'] = 'Danish'
healthHospW_7['education'] = 'No higher education'

# Women, age 30-39, Danish, Higher education
healthHospW_8 = pd.concat(file_list_health_hosp_w[49:56], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_8.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_8['gender'] = 'Women'
healthHospW_8['age'] = '30-39'
healthHospW_8['ethnicity'] = 'Danish'
healthHospW_8['education'] = 'Higher education'

# Women, age 30-39, Immigrants and descendants, No higher education
healthHospW_9 = pd.concat(file_list_health_hosp_w[56:63], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_9.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_9['gender'] = 'Women'
healthHospW_9['age'] = '30-39'
healthHospW_9['ethnicity'] = 'Immigrants and descendants'
healthHospW_9['education'] = 'No higher education'

# Women, age 30-39, Immigrants and descendants, Higher education
healthHospW_10 = pd.concat(file_list_health_hosp_w[63:70], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_10.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_10['gender'] = 'Women'
healthHospW_10['age'] = '30-39'
healthHospW_10['ethnicity'] = 'Immigrants and descendants'
healthHospW_10['education'] = 'Higher education'

# Women, age 30-39, Non-western immigrants and descendants, No higher education
healthHospW_11 = pd.concat(file_list_health_hosp_w[70:77], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_11.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_11['gender'] = 'Women'
healthHospW_11['age'] = '30-39'
healthHospW_11['ethnicity'] = 'Non-western immigrants and descendants'
healthHospW_11['education'] = 'No higher education'

# Women, age 30-39, Immigrants and descendants, Higher education
healthHospW_12 = pd.concat(file_list_health_hosp_w[77:84], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_12.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_12['gender'] = 'Women'
healthHospW_12['age'] = '30-39'
healthHospW_12['ethnicity'] = 'Non-western immigrants and descendants'
healthHospW_12['education'] = 'Higher education'

# Women, age 40-49, Danish, No higher education
healthHospW_13 = pd.concat(file_list_health_hosp_w[84:91], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_13.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_13['gender'] = 'Women'
healthHospW_13['age'] = '40-49'
healthHospW_13['ethnicity'] = 'Danish'
healthHospW_13['education'] = 'No higher education'

# Women, age 40-49, Danish, Higher education
healthHospW_14 = pd.concat(file_list_health_hosp_w[91:98], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_14.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_14['gender'] = 'Women'
healthHospW_14['age'] = '40-49'
healthHospW_14['ethnicity'] = 'Danish'
healthHospW_14['education'] = 'Higher education'

# Women, age 40-49, Immigrants and descendants, No higher education
healthHospW_15 = pd.concat(file_list_health_hosp_w[98:105], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_15.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_15['gender'] = 'Women'
healthHospW_15['age'] = '40-49'
healthHospW_15['ethnicity'] = 'Immigrants and descendants'
healthHospW_15['education'] = 'No higher education'

# Women, age 40-49, Immigrants and descendants, Higher education
healthHospW_16 = pd.concat(file_list_health_hosp_w[105:112], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_16.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_16['gender'] = 'Women'
healthHospW_16['age'] = '40-49'
healthHospW_16['ethnicity'] = 'Immigrants and descendants'
healthHospW_16['education'] = 'Higher education'

# Women, age 40-49, Non-western immigrants and descendants, No higher education
healthHospW_17 = pd.concat(file_list_health_hosp_w[112:119], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_17.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_17['gender'] = 'Women'
healthHospW_17['age'] = '40-49'
healthHospW_17['ethnicity'] = 'Non-western immigrants and descendants'
healthHospW_17['education'] = 'No higher education'

# Women, age 40-49, Non-western immigrants and descendants, Higher education
healthHospW_18 = pd.concat(file_list_health_hosp_w[119:126], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_18.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_18['gender'] = 'Women'
healthHospW_18['age'] = '40-49'
healthHospW_18['ethnicity'] = 'Non-western immigrants and descendants'
healthHospW_18['education'] = 'Higher education'

# Women, age 50-59, Danish, No higher education
healthHospW_19 = pd.concat(file_list_health_hosp_w[126:133], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_19.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_19['gender'] = 'Women'
healthHospW_19['age'] = '50-59'
healthHospW_19['ethnicity'] = 'Danish'
healthHospW_19['education'] = 'No higher education'

# Women, age 50-59, Danish, Higher education
healthHospW_20 = pd.concat(file_list_health_hosp_w[133:140], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_20.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_20['gender'] = 'Women'
healthHospW_20['age'] = '50-59'
healthHospW_20['ethnicity'] = 'Danish'
healthHospW_20['education'] = 'Higher education'

# Women, age 50-59, Immigrants and descendants, No higher education
healthHospW_21 = pd.concat(file_list_health_hosp_w[140:147], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_21.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_21['gender'] = 'Women'
healthHospW_21['age'] = '50-59'
healthHospW_21['ethnicity'] = 'Immigrants and descendants'
healthHospW_21['education'] = 'No higher education'

# Women, age 50-59, Immigrants and descendants, Higher education
healthHospW_22 = pd.concat(file_list_health_hosp_w[147:154], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_22.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_22['gender'] = 'Women'
healthHospW_22['age'] = '50-59'
healthHospW_22['ethnicity'] = 'Immigrants and descendants'
healthHospW_22['education'] = 'Higher education'

# Women, age 50-59, Non-western immigrants and descendants, No higher education
healthHospW_23 = pd.concat(file_list_health_hosp_w[154:161], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_23.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_23['gender'] = 'Women'
healthHospW_23['age'] = '50-59'
healthHospW_23['ethnicity'] = 'Non-western immigrants and descendants'
healthHospW_23['education'] = 'No higher education'

# Women, age 50-59, Non-western immigrants and descendants, Higher education
healthHospW_24 = pd.concat(file_list_health_hosp_w[161:168], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_24.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_24['gender'] = 'Women'
healthHospW_24['age'] = '50-59'
healthHospW_24['ethnicity'] = 'Non-western immigrants and descendants'
healthHospW_24['education'] = 'Higher education'

# Women, age 60-65, Danish, No higher education
healthHospW_25 = pd.concat(file_list_health_hosp_w[168:175], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_25.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_25['gender'] = 'Women'
healthHospW_25['age'] = '60-65'
healthHospW_25['ethnicity'] = 'Danish'
healthHospW_25['education'] = 'No higher education'

# Women, age 60-65, Danish, Higher education
healthHospW_26 = pd.concat(file_list_health_hosp_w[175:182], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_26.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_26['gender'] = 'Women'
healthHospW_26['age'] = '60-65'
healthHospW_26['ethnicity'] = 'Danish'
healthHospW_26['education'] = 'Higher education'

# Women, age 60-65, Immigrants and descendants, No higher education
healthHospW_27 = pd.concat(file_list_health_hosp_w[182:189], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_27.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_27['gender'] = 'Women'
healthHospW_27['age'] = '60-65'
healthHospW_27['ethnicity'] = 'Immigrants and descendants'
healthHospW_27['education'] = 'No higher education'

# Women, age 60-65, Immigrants and descendants, Higher education
healthHospW_28 = pd.concat(file_list_health_hosp_w[189:196], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_28.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_28['gender'] = 'Women'
healthHospW_28['age'] = '60-65'
healthHospW_28['ethnicity'] = 'Immigrants and descendants'
healthHospW_28['education'] = 'Higher education'

# Women, age 60-65, Non-western immigrants and descendants, No higher education
healthHospW_29 = pd.concat(file_list_health_hosp_w[196:203], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_29.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_29['gender'] = 'Women'
healthHospW_29['age'] = '60-65'
healthHospW_29['ethnicity'] = 'Non-western immigrants and descendants'
healthHospW_29['education'] = 'No higher education'

# Women, age 60-65, Non-western immigrants and descendants, Higher education
healthHospW_30 = pd.concat(file_list_health_hosp_w[203:210], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospW_30.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospW_30['gender'] = 'Women'
healthHospW_30['age'] = '60-65'
healthHospW_30['ethnicity'] = 'Non-western immigrants and descendants'
healthHospW_30['education'] = 'Higher education'

# %%
health_hosp_women = pd.concat([healthHospW_1, healthHospW_2, healthHospW_3, healthHospW_4, healthHospW_5, healthHospW_6, healthHospW_7, healthHospW_8, healthHospW_9, healthHospW_10, healthHospW_11, healthHospW_12, healthHospW_13, healthHospW_14, healthHospW_15, healthHospW_16, healthHospW_17, healthHospW_18, healthHospW_19, healthHospW_20, healthHospW_21, healthHospW_22, healthHospW_23, healthHospW_24, healthHospW_25, healthHospW_26, healthHospW_27, healthHospW_28, healthHospW_29, healthHospW_30], axis=0, ignore_index=True)

# %% [markdown]
# ## Health data for Number of Hospitalizations, men
#
# * prep in chunks of seven files. Seven because the next seven files contain the exact same categories that must be added, but are just files for different municipalities.
# * Remove duplicate rows and keep first, as each file contains a row for municipality_code = 0, which is Total Denmark Average. As we only need this row one time, we remove the duplicates
# * Create new columns depending on the file chunk.

# %%
# Input all csv files at once
path = "Health_Hospitalizations_Men/"
all_files_health_hosp_m = glob.glob(path + "/*.csv")
# sort all files by date modified
all_files_health_hosp_m.sort(key=os.path.getmtime)

li_mapper_health_hosp_m = map(lambda filename: pd.read_csv(filename, index_col=None, header=0), all_files_health_hosp_m)
file_list_health_hosp_m = list(li_mapper_health_hosp_m)

# %%
# Men, age 18-29, Danish, No higher education
healthHospM_1 = pd.concat(file_list_health_hosp_m[0:7], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_1.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_1['gender'] = 'Men'
healthHospM_1['age'] = '18-29'
healthHospM_1['ethnicity'] = 'Danish'
healthHospM_1['education'] = 'No higher education'

# Men, age 18-29, Danish, Higher education
healthHospM_2 = pd.concat(file_list_health_hosp_m[7:14], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_2.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_2['gender'] = 'Men'
healthHospM_2['age'] = '18-29'
healthHospM_2['ethnicity'] = 'Danish'
healthHospM_2['education'] = 'Higher education'

# Men, age 18-29, Immigrants and descendants, No higher education
healthHospM_3 = pd.concat(file_list_health_hosp_m[14:21], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_3.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_3['gender'] = 'Men'
healthHospM_3['age'] = '18-29'
healthHospM_3['ethnicity'] = 'Immigrants and descendants'
healthHospM_3['education'] = 'No higher education'

# Men, age 18-29, Immigrants and descendants, Higher education
healthHospM_4 = pd.concat(file_list_health_hosp_m[21:28], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_4.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_4['gender'] = 'Men'
healthHospM_4['age'] = '18-29'
healthHospM_4['ethnicity'] = 'Immigrants and descendants'
healthHospM_4['education'] = 'Higher education'

# Men, age 18-29, Non-western immigrants and descendants, No higher education
healthHospM_5 = pd.concat(file_list_health_hosp_m[28:35], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_5.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_5['gender'] = 'Men'
healthHospM_5['age'] = '18-29'
healthHospM_5['ethnicity'] = 'Non-western immigrants and descendants'
healthHospM_5['education'] = 'No higher education'

# Men, age 18-29, Non-western immigrants and descendants, Higher education
healthHospM_6 = pd.concat(file_list_health_hosp_m[35:42], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_6.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_6['gender'] = 'Men'
healthHospM_6['age'] = '18-29'
healthHospM_6['ethnicity'] = 'Non-western immigrants and descendants'
healthHospM_6['education'] = 'Higher education'

# Men, age 30-39, Danish, No higher education
healthHospM_7 = pd.concat(file_list_health_hosp_m[42:49], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_7.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_7['gender'] = 'Men'
healthHospM_7['age'] = '30-39'
healthHospM_7['ethnicity'] = 'Danish'
healthHospM_7['education'] = 'No higher education'

# Men, age 30-39, Danish, Higher education
healthHospM_8 = pd.concat(file_list_health_hosp_m[49:56], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_8.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_8['gender'] = 'Men'
healthHospM_8['age'] = '30-39'
healthHospM_8['ethnicity'] = 'Danish'
healthHospM_8['education'] = 'Higher education'

# Men, age 30-39, Immigrants and descendants, No higher education
healthHospM_9 = pd.concat(file_list_health_hosp_m[56:63], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_9.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_9['gender'] = 'Men'
healthHospM_9['age'] = '30-39'
healthHospM_9['ethnicity'] = 'Immigrants and descendants'
healthHospM_9['education'] = 'No higher education'

# Men, age 30-39, Immigrants and descendants, Higher education
healthHospM_10 = pd.concat(file_list_health_hosp_m[63:70], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_10.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_10['gender'] = 'Men'
healthHospM_10['age'] = '30-39'
healthHospM_10['ethnicity'] = 'Immigrants and descendants'
healthHospM_10['education'] = 'Higher education'

# Men, age 30-39, Non-western immigrants and descendants, No higher education
healthHospM_11 = pd.concat(file_list_health_hosp_m[70:77], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_11.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_11['gender'] = 'Men'
healthHospM_11['age'] = '30-39'
healthHospM_11['ethnicity'] = 'Non-western immigrants and descendants'
healthHospM_11['education'] = 'No higher education'

# Men, age 30-39, Immigrants and descendants, Higher education
healthHospM_12 = pd.concat(file_list_health_hosp_m[77:84], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_12.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_12['gender'] = 'Men'
healthHospM_12['age'] = '30-39'
healthHospM_12['ethnicity'] = 'Non-western immigrants and descendants'
healthHospM_12['education'] = 'Higher education'

# Men, age 40-49, Danish, No higher education
healthHospM_13 = pd.concat(file_list_health_hosp_m[84:91], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_13.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_13['gender'] = 'Men'
healthHospM_13['age'] = '40-49'
healthHospM_13['ethnicity'] = 'Danish'
healthHospM_13['education'] = 'No higher education'

# Men, age 40-49, Danish, Higher education
healthHospM_14 = pd.concat(file_list_health_hosp_m[91:98], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_14.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_14['gender'] = 'Men'
healthHospM_14['age'] = '40-49'
healthHospM_14['ethnicity'] = 'Danish'
healthHospM_14['education'] = 'Higher education'

# Men, age 40-49, Immigrants and descendants, No higher education
healthHospM_15 = pd.concat(file_list_health_hosp_m[98:105], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_15.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_15['gender'] = 'Men'
healthHospM_15['age'] = '40-49'
healthHospM_15['ethnicity'] = 'Immigrants and descendants'
healthHospM_15['education'] = 'No higher education'

# Men, age 40-49, Immigrants and descendants, Higher education
healthHospM_16 = pd.concat(file_list_health_hosp_m[105:112], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_16.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_16['gender'] = 'Men'
healthHospM_16['age'] = '40-49'
healthHospM_16['ethnicity'] = 'Immigrants and descendants'
healthHospM_16['education'] = 'Higher education'

# Men, age 40-49, Non-western immigrants and descendants, No higher education
healthHospM_17 = pd.concat(file_list_health_hosp_m[112:119], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_17.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_17['gender'] = 'Men'
healthHospM_17['age'] = '40-49'
healthHospM_17['ethnicity'] = 'Non-western immigrants and descendants'
healthHospM_17['education'] = 'No higher education'

# Men, age 40-49, Non-western immigrants and descendants, Higher education
healthHospM_18 = pd.concat(file_list_health_hosp_m[119:126], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_18.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_18['gender'] = 'Men'
healthHospM_18['age'] = '40-49'
healthHospM_18['ethnicity'] = 'Non-western immigrants and descendants'
healthHospM_18['education'] = 'Higher education'

# Men, age 50-59, Danish, No higher education
healthHospM_19 = pd.concat(file_list_health_hosp_m[126:133], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_19.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_19['gender'] = 'Men'
healthHospM_19['age'] = '50-59'
healthHospM_19['ethnicity'] = 'Danish'
healthHospM_19['education'] = 'No higher education'

# Men, age 50-59, Danish, Higher education
healthHospM_20 = pd.concat(file_list_health_hosp_m[133:140], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_20.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_20['gender'] = 'Men'
healthHospM_20['age'] = '50-59'
healthHospM_20['ethnicity'] = 'Danish'
healthHospM_20['education'] = 'Higher education'

# Men, age 50-59, Immigrants and descendants, No higher education
healthHospM_21 = pd.concat(file_list_health_hosp_m[140:147], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_21.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_21['gender'] = 'Men'
healthHospM_21['age'] = '50-59'
healthHospM_21['ethnicity'] = 'Immigrants and descendants'
healthHospM_21['education'] = 'No higher education'

# Men, age 50-59, Immigrants and descendants, Higher education
healthHospM_22 = pd.concat(file_list_health_hosp_m[147:154], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_22.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_22['gender'] = 'Men'
healthHospM_22['age'] = '50-59'
healthHospM_22['ethnicity'] = 'Immigrants and descendants'
healthHospM_22['education'] = 'Higher education'

# Men, age 50-59, Non-western immigrants and descendants, No higher education
healthHospM_23 = pd.concat(file_list_health_hosp_m[154:161], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_23.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_23['gender'] = 'Men'
healthHospM_23['age'] = '50-59'
healthHospM_23['ethnicity'] = 'Non-western immigrants and descendants'
healthHospM_23['education'] = 'No higher education'

# Men, age 50-59, Non-western immigrants and descendants, Higher education
healthHospM_24 = pd.concat(file_list_health_hosp_m[161:168], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_24.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_24['gender'] = 'Men'
healthHospM_24['age'] = '50-59'
healthHospM_24['ethnicity'] = 'Non-western immigrants and descendants'
healthHospM_24['education'] = 'Higher education'

# Men, age 60-65, Danish, No higher education
healthHospM_25 = pd.concat(file_list_health_hosp_m[168:175], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_25.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_25['gender'] = 'Men'
healthHospM_25['age'] = '60-65'
healthHospM_25['ethnicity'] = 'Danish'
healthHospM_25['education'] = 'No higher education'

# Men, age 60-65, Danish, Higher education
healthHospM_26 = pd.concat(file_list_health_hosp_m[175:182], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_26.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_26['gender'] = 'Men'
healthHospM_26['age'] = '60-65'
healthHospM_26['ethnicity'] = 'Danish'
healthHospM_26['education'] = 'Higher education'

# Men, age 60-65, Immigrants and descendants, No higher education
healthHospM_27 = pd.concat(file_list_health_hosp_m[182:189], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_27.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_27['gender'] = 'Men'
healthHospM_27['age'] = '60-65'
healthHospM_27['ethnicity'] = 'Immigrants and descendants'
healthHospM_27['education'] = 'No higher education'

# Men, age 60-65, Immigrants and descendants, Higher education
healthHospM_28 = pd.concat(file_list_health_hosp_m[189:196], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_28.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_28['gender'] = 'Men'
healthHospM_28['age'] = '60-65'
healthHospM_28['ethnicity'] = 'Immigrants and descendants'
healthHospM_28['education'] = 'Higher education'

# Men, age 60-65, Non-western immigrants and descendants, No higher education
healthHospM_29 = pd.concat(file_list_health_hosp_m[196:203], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_29.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_29['gender'] = 'Men'
healthHospM_29['age'] = '60-65'
healthHospM_29['ethnicity'] = 'Non-western immigrants and descendants'
healthHospM_29['education'] = 'No higher education'

# Men, age 60-65, Non-western immigrants and descendants, Higher education
healthHospM_30 = pd.concat(file_list_health_hosp_m[203:210], axis=0, ignore_index=True)
# Remove duplicate rows
healthHospM_30.drop_duplicates(keep='first', inplace=True)
# Create new columns
healthHospM_30['gender'] = 'Men'
healthHospM_30['age'] = '60-65'
healthHospM_30['ethnicity'] = 'Non-western immigrants and descendants'
healthHospM_30['education'] = 'Higher education'

# %%
health_hosp_men = pd.concat([healthHospM_1, healthHospM_2, healthHospM_3, healthHospM_4, healthHospM_5, healthHospM_6, healthHospM_7, healthHospM_8, healthHospM_9, healthHospM_10, healthHospM_11, healthHospM_12, healthHospM_13, healthHospM_14, healthHospM_15, healthHospM_16, healthHospM_17, healthHospM_18, healthHospM_19, healthHospM_20, healthHospM_21, healthHospM_22, healthHospM_23, healthHospM_24, healthHospM_25, healthHospM_26, healthHospM_27, healthHospM_28, healthHospM_29, healthHospM_30], axis=0, ignore_index=True)

# %% [markdown]
# ## Prep hospitalizations data frame
#
# * Concatenate
# * Change column names
# * Sort
# * Rearrange columns
# * Rearrange index
# * Save to csv

# %%
health_hosp = pd.concat([health_hosp_women, health_hosp_men], axis=0, ignore_index=True)

# change column names
health_hosp.rename(columns={'vaerdi': 'number of hospitalizations', 'kommunekode': 'municipality code', 
                       'antal observationer': 'number of hospitalizations observations', 'aar': 'year'}, inplace=True)

# %%
# Add Copenhagen municipality code

# remove municipality code 0 for denmark average
cop = health_hosp[health_hosp['municipality code'] != 0]

# calculate sum of number of hospitalizations observations for all municipalities grouped by other parameters
cop_obs_sum = cop.groupby(['year', 'gender', 'age', 'ethnicity', 'education'])['number of hospitalizations observations'].sum().reset_index().rename(columns={'number of hospitalizations observations': 'hosp_obs_sum'})
cop = pd.merge(cop, cop_obs_sum, on=['year', 'gender', 'age', 'ethnicity', 'education'], how='outer')

# calculate weighted observations and weighted number of hospitalizations
cop['weighted_obs'] = cop['number of hospitalizations observations']/cop['hosp_obs_sum']
cop['weighted_hosp'] = cop['number of hospitalizations']*cop['weighted_obs']

# calculate average number of hospitalizations for copenhagen
cop_hosp_sum = cop.groupby(['year', 'gender', 'age', 'ethnicity', 'education'])['weighted_hosp'].sum().reset_index().rename(columns={'weighted_hosp': 'cop_hosp_avg'})
cop = pd.merge(cop, cop_hosp_sum, on=['year', 'gender', 'age', 'ethnicity', 'education'], how='outer')

# convert copenhagen column to a single row grouped by other parameters
cop = cop.groupby(['year', 'gender', 'age', 'ethnicity', 'education']).mean()
# choose only the columns we need
cop = cop[['cop_hosp_avg', 'hosp_obs_sum']]
# rename the columns
cop = cop.rename(columns={'cop_hosp_avg': 'number of hospitalizations', 'hosp_obs_sum': 'number of hospitalizations observations'})
cop['municipality code'] = '1'
cop.reset_index(inplace=True)

# add the copenhagen row to the health_hosp dataframe
health_hosp = pd.concat([health_hosp, cop], ignore_index=True)

# %%
# calculate weighted observations and weighted income for all municipalities by year
mun_hosp_obs_sum = health_hosp.groupby(['municipality code', 'year'])['number of hospitalizations observations'].sum().reset_index().rename(columns={'number of hospitalizations observations': 'hosp_obs_mun_sum'})
health_hosp = pd.merge(health_hosp, mun_hosp_obs_sum, on=['municipality code', 'year'], how='outer')

# calculate weighted observations and weighted income
health_hosp['weighted_obs_mun'] = health_hosp['number of hospitalizations observations']/health_hosp['hosp_obs_mun_sum']
health_hosp['weighted_hospitalizations_mun'] = health_hosp['number of hospitalizations']*health_hosp['weighted_obs_mun']

# %%
# sort values
health_hosp.sort_values(by=['municipality code', 'year', 'gender', 'age', 'ethnicity', 'education'], inplace=True)

# order columns
cols = ['municipality code', 'year', 'gender', 'age', 'ethnicity', 'education', 'number of hospitalizations', 'number of hospitalizations observations', 'weighted_hospitalizations_mun']
health_hosp = health_hosp[cols]

# start index at 1
health_hosp.index = np.arange(1, len(health_hosp) + 1)

# save to csv
health_hosp.to_csv('health_hosp.csv', index=False)
